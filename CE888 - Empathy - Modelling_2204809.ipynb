# %% [markdown]
# ## CE888 - Data Science and Decision Making

# %% [markdown]
# ## AN INVESTIGATION OF ASSESSMENT OF EMPATHY USING EYE TRACKING DATA

# %% [markdown]
# #### REGISTRATION NUMBER - 2204809

# %% [markdown]
# #### Importing the required libraries

# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 10)
np.set_printoptions(precision = 3)
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
import scipy
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import LeaveOneOut
from sklearn.metrics import mean_squared_error
from math import sqrt

# %% [markdown]
# #### Helper functions

# %%
#function to merge the dataset
def merge_csv(directory):
    files = os.listdir(directory)
    data = pd.DataFrame()
    for file in files:
        if file.endswith('.csv'):
            data = pd.concat([data, pd.read_csv(os.path.join(directory, file), usecols=["Computer timestamp", "Participant name", 'Recording name','Gaze point X','Gaze point Y', 'Pupil diameter left', 'Pupil diameter right', 'Eye movement type', 'Gaze event duration', 'Eye movement type index'])])
            
    return data

# %%
#function to read and merge the dataset into a dictionary of dataframes 
def merge_csv_dict(directory):
    files = os.listdir(directory)
    data = {}
    for file in files:
        if file.endswith('.csv'):
            data[file.split('participant')[1]] = pd.read_csv(os.path.join(directory, file), usecols=["Computer timestamp", "Participant name", 'Recording name','Gaze point X','Gaze point Y', 'Pupil diameter left', 'Pupil diameter right', 'Eye movement type', 'Gaze event duration', 'Eye movement type index'])
    return data

# %%
#function to parse the participant id
def parse_participant_id(col):
    for i in range(0, len(col)):
        col[i] = col[i][-2:]
    return col

# %%
#function to parse the recording name
def parse_recording_name(col):
    for i in range(0, len(col)):
        col[i] = col[i].split('g')[1]
    return col

# %%
#function to compress the dataset into one row per trial
def compress_trials(df, i):
    trials_data = pd.DataFrame()
    #print(df['Participant'].i~loc[0])
    trials_data.at[i,'Participant'] = df['Participant'].iloc[0]
    trials_data.at[i,'Recording name'] = df['Recording name'].iloc[0]
    trials_data.at[i,'Gaze point X'] = df['Gaze point X'].mean()
    trials_data.at[i,'Gaze point Y'] = df['Gaze point Y'].mean()
    trials_data.at[i,'Gaze event duration - Max'] = df['Gaze event duration - Max'].mean()
    trials_data.at[i,'Left pupil (max-mean)'] = df['Left pupil (max-mean)'].mean()
    trials_data.at[i,'Right pupil (max-mean)'] = df['Right pupil (max-mean)'].mean()
    trials_data.at[i,'Left pupil (mean-min)'] = df['Left pupil (mean-min)'].mean()
    trials_data.at[i,'Right pupil (mean-min)'] = df['Right pupil (mean-min)'].mean()
    trials_data.at[i,'Eye movement type_Fixation'] = df['Eye movement type_Fixation'].mean()
    trials_data.at[i,'Eye movement type_Saccade'] = df['Eye movement type_Saccade'].mean()
    trials_data.at[i,'Eye movement type_Unclassified'] = df['Eye movement type_Unclassified'].mean()
    return trials_data

# %%
#automating the pre-processing 
def pre_pros(df):
    df['Pupil diameter left'] = df['Pupil diameter left'].str.replace(',', '.').astype('float64')
    df['Pupil diameter right'] = df['Pupil diameter right'].str.replace(',', '.').astype('float64')
    df['Left pupil (max-mean)'] = df['Pupil diameter left'].max() - df['Pupil diameter left'].mean()
    df['Right pupil (max-mean)'] = df['Pupil diameter right'].max() - df['Pupil diameter right'].mean()
    df['Left pupil (mean-min)'] = df['Pupil diameter left'].mean() - df['Pupil diameter left'].min()
    df['Right pupil (mean-min)'] = df['Pupil diameter right'].mean() - df['Pupil diameter right'].min()
    col = {'Eye movement type'}
    df = pd.get_dummies(df, columns=col)
    df['Eye movement type_Unclassified'] = df['Eye movement type_Unclassified'].sum()
    df['Eye movement type_Saccade'] = df['Eye movement type_Saccade'].sum()
    df['Eye movement type_Fixation'] = df['Eye movement type_Fixation'].sum()
    df['Gaze event duration - Max'] = df['Gaze event duration'].max()
    df = df.reset_index()
    df['Recording name'] = parse_recording_name(df['Recording name'])
    df['Recording name'] = df['Recording name'].apply(pd.to_numeric)
    df.rename(columns={'Participant name': 'Participant'}, inplace=True)
    df['Participant'] = parse_participant_id(df['Participant'])
    df['Participant'] = df['Participant'].apply(pd.to_numeric)
    return df

# %% [markdown]
# ### Loading the questionnaire data to extract the empathy scores

# %%
#q_IA contains the questionnaire data 'before intervention' or before conducting the experiment
q_IA = pd.read_csv(r"C:\Users\vk22372\Questionnaire_datasetIA.csv", encoding= 'unicode_escape')
q_IA.head()
# Out:
#    Participant nr       NR           Created          Modified  \
# 0               1  9199452  07.09.2020 15:13  07.09.2020 15:13
# 1               2  9584002  30.09.2020 11:23  30.09.2020 11:23
# 2               3  9112363  02.09.2020 09:17  02.09.2020 09:17
# 3               4  9727754  06.10.2020 13:20  06.10.2020 13:20
# 4               5  9730232  06.10.2020 14:53  06.10.2020 14:53
#
#   I have read and understood the information about the study and all the information in this form is explained to me and I am willing to participate  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   I want to participate.  \
# 0                Proceed
# 1                Proceed
# 2                Proceed
# 3                Proceed
# 4                Proceed
#
#    I sometimes find it difficult to see things from the other guys point of view.  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  2
# 4                                                  3
#
#    I am usually objective when I watch a film or play, and I dont often get completely caught up in it.  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  3
#
#    I try to look at everybodys side of a disagreement before I make a decision.  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    I sometimes try to understand my friends better by imagining how things look from their perspective.  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    When I am upset at someone, I usually try to put myself in his shoes for a while.  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
# 3                                                  2
# 4                                                  3
#
#    Before criticising somebody, I try to imagine how I would feel if I was in their place.  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    I often get emotionally involved with my friends problems.  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    I am inclined to get nervous when others around me seem to be nervous.  \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  4
# 4                                                  1
#
#    People I am with have a strong influence on my mood.  \
# 0                                                  2
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    It affects me very much when one of my friends seems upset.  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    I often get deeply involved with the feelings of a character in a film, play or novel.  \
# 0                                                  3
# 1                                                  1
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    I get very upset when I see someone cry.  \
# 0                                         4
# 1                                         3
# 2                                         4
# 3                                         3
# 4                                         3
#
#    I am happy when I am with a cheerful group and sad when the others are glum.  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    It worries me when others are worrying and panicky.  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
# 3                                                  3
# 4                                                  2
#
#    I can easily tell if someone else wants to enter a conversation.  \
# 0                                                  3
# 1                                                  4
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    I can pick up quickly if someone says one thing but means another.  \
# 0                                                  4
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    It is hard for me to see why some things upset people so much.  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    I find it easy to put myself in somebody elses shoes.  \
# 0                                                  4
# 1                                                  4
# 2                                                  2
# 3                                                  3
# 4                                                  2
#
#    I am good at predicting how someone will feel.  \
# 0                                               4
# 1                                               4
# 2                                               2
# 3                                               3
# 4                                               3
#
#    I am quick to spot when someone in a group is feeling awkward or uncomfortable.  \
# 0                                                  4
# 1                                                  3
# 2                                                  2
# 3                                                  4
# 4                                                  4
#
#    Other people tell me I am good at understanding how they are feeling and what they are thinking.  \
# 0                                                  4
# 1                                                  4
# 2                                                  2
# 3                                                  4
# 4                                                  4
#
#    I can easily tell if someone else is interested or bored with what I am saying.  \
# 0                                                  4
# 1                                                  4
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    Friends talk to me about their problems as they say that I am very understanding.  \
# 0                                                  4
# 1                                                  4
# 2                                                  2
# 3                                                  4
# 4                                                  4
#
#    I can sense if I am intruding, even if the other person does not tell me.  \
# 0                                                  4
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    I can easily work out what another person might want to talk about.  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    I can tell if someone is masking their true emotion.  \
# 0                                                  3
# 1                                                  4
# 2                                                  2
# 3                                                  4
# 4                                                  4
#
#    I am good at predicting what someone will do.  \
# 0                                              3
# 1                                              3
# 2                                              2
# 3                                              2
# 4                                              3
#
#    I can usually appreciate the other persons viewpoint, even if I do not agree with it.  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  1
# 4                                                  3
#
#    I usually stay emotionally detached when watching a film.  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  2
# 4                                                  4
#
#    I always try to consider the other fellows feelings before I do something.  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    Before I do something I try to consider how my friends will react to it.  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    I feel frustrated when I cannot communicate my ideas.  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  1
# 4                                                  4
#
#    I complete the sentences of other people when they find it difficult to communicate their ideas to help them.  \
# 0                                                  4
# 1                                                  4
# 2                                                  2
# 3                                                  4
# 4                                                  3
#
#    If someone is suffering from stutter, I prefer speaking rather than texting.  \
# 0                                                  1
# 1                                                  2
# 2                                                  3
# 3                                                  2
# 4                                                  1
#
#    I try to be patient when people speak with me very slowly.  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    In a situation, when there are handicapped students in a classroom, the pace of the class should be adapted to the handicapped student.  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  4
# 4                                                  2
#
#    In a situation, when there are only one handicapped student in a classroom, the pace of the class should be adapted to him/her independently of how many students are in the class.  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  4
# 4                                                  1
#
#    I feel impatient when people communicate slowly, so I complete other peoples sentences to make the communication more efficient.  \
# 0                                                  1
# 1                                                  4
# 2                                                  3
# 3                                                  2
# 4                                                  4
#
#    I believe that the handicapped students should catch the pace of the group in a classroom to not delay the progress of other students.  \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    I feel left out (or excluded) when I cannot participate in a conversation.  \
# 0                                                  4
# 1                                                  2
# 2                                                  3
# 3                                                  2
# 4                                                  4
#
#    Total Score extended  Total Score original          Elapsed time
# 0                   134                   108   5 minutes 5 seconds
# 1                   133                   105  5 minutes 55 seconds
# 2                   116                    81  6 minutes 49 seconds
# 3                   114                    96  8 minutes 39 seconds
# 4                   138                   106  7 minutes 27 seconds

# %%
#q_IB contains the questionnaire data 'after intervention' or after conducting the experiment
q_IB = pd.read_csv(r"C:\Users\vk22372\Questionnaire_datasetIB.csv", encoding= 'unicode_escape')
q_IB.head()
# Out:
#    Participant nr       NR           Created          Modified  \
# 0               1  9534500  24.09.2020 16:00  24.09.2020 16:00
# 1               2  9597659  30.09.2020 15:14  30.09.2020 15:14
# 2               3  9637453  01.10.2020 16:20  01.10.2020 16:20
# 3               4  9732460  06.10.2020 16:45  06.10.2020 16:45
# 4               5  9732853  06.10.2020 17:24  06.10.2020 17:24
#
#   I have read and understood the information about the study and all the information in this form is explained to me and I am willing to participate  \
# 0                                                Yes
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   I want to participate.  \
# 0                Proceed
# 1                Proceed
# 2                Proceed
# 3                Proceed
# 4                Proceed
#
#    I sometimes find it difficult to see things from the other guys point of view.  \
# 0                                                  1
# 1                                                  2
# 2                                                  4
# 3                                                  2
# 4                                                  2
#
#    I am usually objective when I watch a film or play, and I dont often get completely caught up in it.  \
# 0                                                  3
# 1                                                  2
# 2                                                  1
# 3                                                  3
# 4                                                  3
#
#    I try to look at everybodys side of a disagreement before I make a decision.  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    I sometimes try to understand my friends better by imagining how things look from their perspective.  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  3
# 4                                                  3
#
#    When I am upset at someone, I usually try to put myself in his shoes for a while.  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  2
# 4                                                  3
#
#    Before criticising somebody, I try to imagine how I would feel if I was in their place.  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    I often get emotionally involved with my friends problems.  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  4
#
#    I am inclined to get nervous when others around me seem to be nervous.  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  2
#
#    People I am with have a strong influence on my mood.  \
# 0                                                  3
# 1                                                  4
# 2                                                  3
# 3                                                  3
# 4                                                  2
#
#    It affects me very much when one of my friends seems upset.  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    I often get deeply involved with the feelings of a character in a film, play or novel.  \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    I get very upset when I see someone cry.  \
# 0                                         3
# 1                                         3
# 2                                         4
# 3                                         4
# 4                                         3
#
#    I am happy when I am with a cheerful group and sad when the others are glum.  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  3
#
#    It worries me when others are worrying and panicky.  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  1
#
#    I can easily tell if someone else wants to enter a conversation.  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    I can pick up quickly if someone says one thing but means another.  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    It is hard for me to see why some things upset people so much.  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    I find it easy to put myself in somebody elses shoes.  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  3
# 4                                                  3
#
#    I am good at predicting how someone will feel.  \
# 0                                               4
# 1                                               3
# 2                                               3
# 3                                               3
# 4                                               4
#
#    I am quick to spot when someone in a group is feeling awkward or uncomfortable.  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    Other people tell me I am good at understanding how they are feeling and what they are thinking.  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    I can easily tell if someone else is interested or bored with what I am saying.  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    Friends talk to me about their problems as they say that I am very understanding.  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#    I can sense if I am intruding, even if the other person does not tell me.  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    I can easily work out what another person might want to talk about.  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  3
#
#    I can tell if someone is masking their true emotion.  \
# 0                                                  3
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  4
#
#    I am good at predicting what someone will do.  \
# 0                                              3
# 1                                              3
# 2                                              2
# 3                                              3
# 4                                              3
#
#    I can usually appreciate the other persons viewpoint, even if I do not agree with it.  \
# 0                                                  4
# 1                                                  4
# 2                                                  4
# 3                                                  1
# 4                                                  1
#
#    I usually stay emotionally detached when watching a film.  \
# 0                                                  3
# 1                                                  3
# 2                                                  3
# 3                                                  2
# 4                                                  3
#
#    I always try to consider the other fellows feelings before I do something.  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  3
# 4                                                  3
#
#    Before I do something I try to consider how my friends will react to it.  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  4
# 4                                                  3
#
#    I feel frustrated when I cannot communicate my ideas.  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  1
# 4                                                  4
#
#    I complete the sentences of other people when they find it difficult to communicate their ideas to help them.  \
# 0                                                  4
# 1                                                  4
# 2                                                  2
# 3                                                  4
# 4                                                  2
#
#    If someone is suffering from stutter, I prefer speaking rather than texting.  \
# 0                                                  1
# 1                                                  2
# 2                                                  3
# 3                                                  2
# 4                                                  3
#
#    I try to be patient when people speak with me very slowly.  \
# 0                                                  4
# 1                                                  4
# 2                                                  3
# 3                                                  3
# 4                                                  4
#
#    In a situation, when there are handicapped students in a classroom, the pace of the class should be adapted to the handicapped student.  \
# 0                                                  4
# 1                                                  3
# 2                                                  3
# 3                                                  4
# 4                                                  2
#
#    In a situation, when there are only one handicapped student in a classroom, the pace of the class should be adapted to him/her independently of how many students are in the class.  \
# 0                                                  4
# 1                                                  3
# 2                                                  2
# 3                                                  3
# 4                                                  1
#
#    I feel impatient when people communicate slowly, so I complete other peoples sentences to make the communication more efficient.  \
# 0                                                  1
# 1                                                  4
# 2                                                  3
# 3                                                  2
# 4                                                  4
#
#    I believe that the handicapped students should catch the pace of the group in a classroom to not delay the progress of other students.  \
# 0                                                  2
# 1                                                  2
# 2                                                  3
# 3                                                  4
# 4                                                  3
#
#    I feel left out (or excluded) when I cannot participate in a conversation.  \
# 0                                                  4
# 1                                                  2
# 2                                                  2
# 3                                                  2
# 4                                                  4
#
#    Total Score extended  Total Score original          Elapsed time
# 0                   137                   109   5 minutes 5 seconds
# 1                   127                   100  5 minutes 55 seconds
# 2                   123                    98  6 minutes 49 seconds
# 3                   120                    95  8 minutes 39 seconds
# 4                   124                    97  7 minutes 27 seconds

# %% [markdown]
# According to the paper, questions Q1, Q2, Q27, Q30, Q36 and Q37 have reverse scoring. On analysing the questions and how they relate to empathy, we can observe that the questions that actually need reverse scoring are Q1, Q2, Q17, Q29, Q34, Q38, Q39. Hence, the scores for questions Q27, Q30, Q36, Q37, Q17, Q29, Q34, Q38, Q39 actually need to be reversed in order to get a proper empathy score. This is carried out in the next cell.

# %%
replace_struct = {'It is hard for me to see why some things upset people so much.':{1:4, 2:3, 3:2, 4:1},
                 'I am good at predicting how someone will feel.':{1:4, 2:3, 3:2, 4:1},
                 'I usually stay emotionally detached when watching a film.':{1:4, 2:3, 3:2, 4:1},
                 'I always try to consider the other fellows feelings before I do something.':{1:4, 2:3, 3:2, 4:1},
                 'If someone is suffering from stutter, I prefer speaking rather than texting.':{1:4, 2:3, 3:2, 4:1},
                 'In a situation, when there are handicapped students in a classroom, the pace of the class should be adapted to the handicapped student.':{1:4, 2:3, 3:2, 4:1},
                 'In a situation, when there are only one handicapped student in a classroom, the pace of the class should be adapted to him/her independently of how many students are in the class.':{1:4, 2:3, 3:2, 4:1},
                 'I feel impatient when people communicate slowly, so I complete other people’s sentences to make the communication more efficient.':{1:4, 2:3, 3:2, 4:1},
                 'I believe that the handicapped students should catch the pace of the group in a classroom to not delay the progress of other students.':{1:4, 2:3, 3:2, 4:1}}
q_IA = q_IA.replace(replace_struct)
q_IB = q_IB.replace(replace_struct)

# %% [markdown]
# Removing the unnecessary columns from the questionnaire and retaining only the total score column as calculated by the authors for simplicity .

# %%
cols = ['Participant nr', 'NR', 'Created', 'Modified', 'Total Score extended', 'Total Score original', 'Elapsed time', 'I have read and understood the information about the study and all the information in this form is explained to me and I am willing to participate', 'I want to participate.']
Q_IA = q_IA.drop(cols, axis=1)
Q_IA = Q_IA.T
Q_IA_ext_score = Q_IA.sum()

# %%
rows = ['I feel left out (or excluded) when I cannot participate in a conversation.',
        'I believe that the handicapped students should catch the pace of the group in a classroom to not delay the progress of other students.',
        'I feel impatient when people communicate slowly, so I complete other peoples sentences to make the communication more efficient.',
        'In a situation, when there are only one handicapped student in a classroom, the pace of the class should be adapted to him/her independently of how many students are in the class.',
        'In a situation, when there are handicapped students in a classroom, the pace of the class should be adapted to the handicapped student.',
        'I try to be patient when people speak with me very slowly.',
        'If someone is suffering from stutter, I prefer speaking rather than texting.',
        'I complete the sentences of other people when they find it difficult to communicate their ideas to help them.',
        'I feel frustrated when I cannot communicate my ideas.']
Q_IA = Q_IA.T
Q_IA = Q_IA.drop(rows, axis=1)
Q_IA = Q_IA.T
Q_IA_og_score = Q_IA.sum()

# %%
Q_IB = q_IB.drop(cols, axis=1)
Q_IB = Q_IB.T
Q_IB_ext_score = Q_IB.sum()

# %%
Q_IB = Q_IB.T
Q_IB = Q_IB.drop(rows, axis=1)
Q_IB = Q_IB.T
Q_IB_og_score = Q_IB.sum()

# %%
#storing all the scores in one dataframe 
d = { 'Participant':range(1, len(Q_IA_ext_score)+1), 'Q_IA_og':Q_IA_og_score, 'Q_IA_ext':Q_IA_ext_score, 'Q_IB_og':Q_IB_og_score, 'Q_IB_ext':Q_IB_ext_score}
emp_score = pd.DataFrame(data=d)
emp_score
# Out:
#     Participant  Q_IA_og  Q_IA_ext  Q_IB_og  Q_IB_ext
# 0             1      100       125      101       127
# 1             2       97       124       94       121
# 2             3       81       103       94       117
# 3             4       92       110       93       112
# 4             5       96       127       91       120
# ..          ...      ...       ...      ...       ...
# 55           56       71        92       82       102
# 56           57      101       127      102       124
# 57           58       94       121       54        72
# 58           59       99       125       97       122
# 59           60       94       119       60        78
#
# [60 rows x 5 columns]

# %%
#Adding classes to the empathy scores to do further analysis 
emp_score['Class'] = 1
emp_score.loc[emp_score['Q_IB_og'] > 60, 'Class'] = 2
emp_score.loc[emp_score['Q_IB_og'] > 80, 'Class'] = 3
emp_score.loc[emp_score['Q_IB_og'] > 100, 'Class'] = 4

# %%
emp_score[emp_score['Class'] == 4]
# Out:
#     Participant  Q_IA_og  Q_IA_ext  Q_IB_og  Q_IB_ext  Class
# 0             1      100       125      101       127      4
# 10           11       99       118      109       131      4
# 13           14      109       135      102       128      4
# 14           15      100       125      101       125      4
# 19           20       95       117      106       132      4
# 28           29       99       126      105       129      4
# 34           35      103       129      107       133      4
# 36           37      102       129      101       126      4
# 56           57      101       127      102       124      4

# %%
#Final Empathy Score Dataset
emp_score.head(9)
# Out:
#    Participant  Q_IA_og  Q_IA_ext  Q_IB_og  Q_IB_ext  Class
# 0            1      100       125      101       127      4
# 1            2       97       124       94       121      3
# 2            3       81       103       94       117      3
# 3            4       92       110       93       112      3
# 4            5       96       127       91       120      3
# 5            6       94       118       93       117      3
# 6            7       81       105       75        99      2
# 7            8       82       106       74        98      2
# 8            9       85       108       80       107      2

# %%
emp_score.describe()
# Out:
#        Participant     Q_IA_og    Q_IA_ext     Q_IB_og    Q_IB_ext      Class
# count    60.000000   60.000000   60.000000   60.000000   60.000000  60.000000
# mean     30.500000   91.583333  115.766667   84.050000  107.500000   2.733333
# std      17.464249    8.473871    9.517810   14.871683   16.741808   0.820638
# min       1.000000   71.000000   92.000000   52.000000   69.000000   1.000000
# 25%      15.750000   85.000000  108.000000   73.750000   97.250000   2.000000
# 50%      30.500000   92.000000  116.000000   86.000000  110.500000   3.000000
# 75%      45.250000   98.250000  125.000000   94.000000  120.250000   3.000000
# max      60.000000  109.000000  135.000000  109.000000  133.000000   4.000000

# %% [markdown]
# ### Importing the entire dataset as a disctionary of datasets

# %%
data = merge_csv_dict(r"C:\Users\vk22372\EyeT")
# Out:
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2855751044.py:7: DtypeWarning: Columns (34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   data[file.split('participant')[1]] = pd.read_csv(os.path.join(directory, file), usecols=["Computer timestamp", "Participant name", 'Recording name','Gaze point X','Gaze point Y', 'Pupil diameter left', 'Pupil diameter right', 'Eye movement type', 'Gaze event duration', 'Eye movement type index'])
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2855751044.py:7: DtypeWarning: Columns (34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   data[file.split('participant')[1]] = pd.read_csv(os.path.join(directory, file), usecols=["Computer timestamp", "Participant name", 'Recording name','Gaze point X','Gaze point Y', 'Pupil diameter left', 'Pupil diameter right', 'Eye movement type', 'Gaze event duration', 'Eye movement type index'])
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2855751044.py:7: DtypeWarning: Columns (34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   data[file.split('participant')[1]] = pd.read_csv(os.path.join(directory, file), usecols=["Computer timestamp", "Participant name", 'Recording name','Gaze point X','Gaze point Y', 'Pupil diameter left', 'Pupil diameter right', 'Eye movement type', 'Gaze event duration', 'Eye movement type index'])
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2855751044.py:7: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   data[file.split('participant')[1]] = pd.read_csv(os.path.join(directory, file), usecols=["Computer timestamp", "Participant name", 'Recording name','Gaze point X','Gaze point Y', 'Pupil diameter left', 'Pupil diameter right', 'Eye movement type', 'Gaze event duration', 'Eye movement type index'])

# %%
temp = data

# %%
keys = data.keys()
data['_11_trial_0.csv']
# Out:
#       Computer timestamp Participant name Recording name  Gaze point X  \
# 0              512092386  Participant0001     Recording1           NaN
# 1              512092386  Participant0001     Recording1           NaN
# 2              512099191  Participant0001     Recording1         962.0
# 3              512107520  Participant0001     Recording1         962.0
# 4              512115853  Participant0001     Recording1         962.0
# ...                  ...              ...            ...           ...
# 7461           572066018  Participant0001     Recording1         462.0
# 7462           572074415  Participant0001     Recording1         482.0
# 7463           572082685  Participant0001     Recording1         480.0
# 7464           572091054  Participant0001     Recording1         529.0
# 7465           572107532  Participant0001     Recording1           NaN
#
#       Gaze point Y Pupil diameter left Pupil diameter right Eye movement type  \
# 0              NaN                 NaN                  NaN          Fixation
# 1              NaN                 NaN                  NaN          Fixation
# 2            346.0                 NaN                  NaN          Fixation
# 3            350.0                 NaN                  NaN          Fixation
# 4            346.0                3,21                 3,14          Fixation
# ...            ...                 ...                  ...               ...
# 7461         201.0                 NaN                  NaN          Fixation
# 7462         218.0                 NaN                  NaN          Fixation
# 7463         213.0                2,92                 2,93          Fixation
# 7464         217.0                 NaN                  NaN          Fixation
# 7465           NaN                 NaN                  NaN               NaN
#
#       Gaze event duration  Eye movement type index
# 0                   117.0                     64.0
# 1                   117.0                     64.0
# 2                   117.0                     64.0
# 3                   117.0                     64.0
# 4                   117.0                     64.0
# ...                   ...                      ...
# 7461                 75.0                    259.0
# 7462                 75.0                    259.0
# 7463                 75.0                    259.0
# 7464                 75.0                    259.0
# 7465                  NaN                      NaN
#
# [7466 rows x 10 columns]

# %% [markdown]
# Based on the analysis carried out, the preprocessing of the data has been automated. Code for the function pre_pros function is above.

# %%
for df in keys :
    data[df] = pre_pros(data[df])
# Out:
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\4048416474.py:9: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df = pd.get_dummies(df, columns=col)
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\1280764481.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i].split('g')[1]
# C:\Users\vk22372\AppData\Local\Temp\ipykernel_2012\2107401625.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[i] = col[i][-2:]

# %%
data['_3_trial_13.csv']
# Out:
#        index  Computer timestamp  Participant  Recording name  Gaze point X  \
# 0          0          1221666122            3              14           NaN
# 1          1          1221666122            3              14           NaN
# 2          2          1221667836            3              14        1507.0
# 3          3          1221676182            3              14        1693.0
# 4          4          1221684521            3              14        1746.0
# ...      ...                 ...          ...             ...           ...
# 18854  18854          1378005744            3              14        2066.0
# 18855  18855          1378013987            3              14        2062.0
# 18856  18856          1378021450            3              14           NaN
# 18857  18857          1378021450            3              14           NaN
# 18858  18858          1378045945            3              14           NaN
#
#        Gaze point Y  Pupil diameter left  Pupil diameter right  \
# 0               NaN                  NaN                   NaN
# 1               NaN                  NaN                   NaN
# 2            1085.0                  NaN                   NaN
# 3            1084.0                 3.23                  3.30
# 4            1069.0                  NaN                   NaN
# ...             ...                  ...                   ...
# 18854         635.0                  NaN                   NaN
# 18855         642.0                 3.24                  3.06
# 18856           NaN                  NaN                   NaN
# 18857           NaN                  NaN                   NaN
# 18858           NaN                  NaN                   NaN
#
#        Gaze event duration  Eye movement type index  Left pupil (max-mean)  \
# 0                     50.0                     38.0               0.927733
# 1                     50.0                     38.0               0.927733
# 2                     50.0                     38.0               0.927733
# 3                     50.0                     38.0               0.927733
# 4                     50.0                     38.0               0.927733
# ...                    ...                      ...                    ...
# 18854                 58.0                   2176.0               0.927733
# 18855                 58.0                   2176.0               0.927733
# 18856                  NaN                      NaN               0.927733
# 18857                  NaN                      NaN               0.927733
# 18858                  NaN                      NaN               0.927733
#
#        Right pupil (max-mean)  Left pupil (mean-min)  Right pupil (mean-min)  \
# 0                    0.886305               1.012267                1.043695
# 1                    0.886305               1.012267                1.043695
# 2                    0.886305               1.012267                1.043695
# 3                    0.886305               1.012267                1.043695
# 4                    0.886305               1.012267                1.043695
# ...                       ...                    ...                     ...
# 18854                0.886305               1.012267                1.043695
# 18855                0.886305               1.012267                1.043695
# 18856                0.886305               1.012267                1.043695
# 18857                0.886305               1.012267                1.043695
# 18858                0.886305               1.012267                1.043695
#
#        Eye movement type_EyesNotFound  Eye movement type_Fixation  \
# 0                                   0                        5778
# 1                                   0                        5778
# 2                                   0                        5778
# 3                                   0                        5778
# 4                                   0                        5778
# ...                               ...                         ...
# 18854                               0                        5778
# 18855                               0                        5778
# 18856                               0                        5778
# 18857                               0                        5778
# 18858                               0                        5778
#
#        Eye movement type_Saccade  Eye movement type_Unclassified  \
# 0                           6748                            5065
# 1                           6748                            5065
# 2                           6748                            5065
# 3                           6748                            5065
# 4                           6748                            5065
# ...                          ...                             ...
# 18854                       6748                            5065
# 18855                       6748                            5065
# 18856                       6748                            5065
# 18857                       6748                            5065
# 18858                       6748                            5065
#
#        Gaze event duration - Max
# 0                          475.0
# 1                          475.0
# 2                          475.0
# 3                          475.0
# 4                          475.0
# ...                          ...
# 18854                      475.0
# 18855                      475.0
# 18856                      475.0
# 18857                      475.0
# 18858                      475.0
#
# [18859 rows x 19 columns]

# %%
trials_data = pd.DataFrame()

# %%
i=0
for df in keys:
    trials_data = pd.concat([trials_data, compress_trials(data[df],i)])
    i += 1

# %%
trials_data
# Out:
#      Participant  Recording name  Gaze point X  Gaze point Y  \
# 0            1.0             1.0   1070.355771    253.597742
# 1            1.0             2.0    965.955342    306.260339
# 2            3.0            11.0   1017.325455    555.689808
# 3            3.0            12.0    984.012235    588.452621
# 4            3.0            13.0   1005.079682    534.013693
# ..           ...             ...           ...           ...
# 497         56.0             4.0    982.199465    636.944157
# 498         58.0             2.0    937.805840    427.840598
# 499         58.0             4.0    943.514611    419.835007
# 500         60.0             2.0    878.143282    421.078113
# 501         60.0             4.0    889.659743    361.861417
#
#      Gaze event duration - Max  Left pupil (max-mean)  Right pupil (max-mean)  \
# 0                       1242.0               0.404153                0.589454
# 1                        717.0               0.472800                0.631475
# 2                        500.0               0.916326                0.548080
# 3                        350.0               0.900668                0.813724
# 4                        325.0               1.114668                0.872575
# ..                         ...                    ...                     ...
# 497                     1067.0               0.609184                1.167508
# 498                     2033.0               1.939853                1.530958
# 499                     2500.0               1.963222                2.037256
# 500                     1433.0               0.419122                0.632128
# 501                     1400.0               0.701815                0.584341
#
#      Left pupil (mean-min)  Right pupil (mean-min)  \
# 0                 1.105847                0.910546
# 1                 0.637200                0.728525
# 2                 0.893674                0.771920
# 3                 1.069332                0.886276
# 4                 1.005332                0.867425
# ..                     ...                     ...
# 497               1.080816                1.342492
# 498               0.960147                1.049042
# 499               0.926778                1.042744
# 500               0.760878                1.457872
# 501               0.938185                1.205659
#
#      Eye movement type_Fixation  Eye movement type_Saccade  \
# 0                        3959.0                     1996.0
# 1                        4235.0                     1909.0
# 2                        2070.0                     2232.0
# 3                        3194.0                     4429.0
# 4                        2605.0                     4969.0
# ..                          ...                        ...
# 497                      1906.0                      990.0
# 498                      5636.0                      913.0
# 499                      4925.0                      754.0
# 500                      5294.0                      997.0
# 501                      5108.0                      954.0
#
#      Eye movement type_Unclassified
# 0                            1115.0
# 1                             842.0
# 2                            1920.0
# 3                            4043.0
# 4                            3920.0
# ..                              ...
# 497                          2747.0
# 498                           501.0
# 499                          1048.0
# 500                           496.0
# 501                           511.0
#
# [502 rows x 12 columns]

# %% [markdown]
# ### Approach 1 - Building different models for test group and control group

# %%
#separating test group participants and the control group participants
control_group = trials_data[trials_data['Participant'] %2 != 0]
test_group = trials_data[trials_data['Participant'] %2 == 0]

# %%
test_group.head()
# Out:
#      Participant  Recording name  Gaze point X  Gaze point Y  \
# 360         10.0             1.0    971.247027    441.096289
# 361         10.0             2.0    978.398370    484.556360
# 362         10.0             3.0    998.712701    554.162540
# 363         10.0             4.0   1003.353020    587.964254
# 364         14.0             2.0   1016.897923    481.736213
#
#      Gaze event duration - Max  Left pupil (max-mean)  Right pupil (max-mean)  \
# 360                     1017.0               0.872613                2.897901
# 361                     3476.0               1.630469                2.920098
# 362                     6567.0               2.002562                2.109127
# 363                    12156.0               1.269191                0.642110
# 364                      575.0               0.841228                0.882427
#
#      Left pupil (mean-min)  Right pupil (mean-min)  \
# 360               0.827387                1.042099
# 361               0.979531                0.829902
# 362               0.907438                0.750873
# 363               0.960809                0.967890
# 364               0.658772                1.117573
#
#      Eye movement type_Fixation  Eye movement type_Saccade  \
# 360                      5392.0                     1164.0
# 361                      5283.0                     1097.0
# 362                      4444.0                     1252.0
# 363                      3389.0                      849.0
# 364                      1182.0                      485.0
#
#      Eye movement type_Unclassified
# 360                           466.0
# 361                           316.0
# 362                           572.0
# 363                           294.0
# 364                          5149.0

# %%
control_group.head()
# Out:
#    Participant  Recording name  Gaze point X  Gaze point Y  \
# 0          1.0             1.0   1070.355771    253.597742
# 1          1.0             2.0    965.955342    306.260339
# 2          3.0            11.0   1017.325455    555.689808
# 3          3.0            12.0    984.012235    588.452621
# 4          3.0            13.0   1005.079682    534.013693
#
#    Gaze event duration - Max  Left pupil (max-mean)  Right pupil (max-mean)  \
# 0                     1242.0               0.404153                0.589454
# 1                      717.0               0.472800                0.631475
# 2                      500.0               0.916326                0.548080
# 3                      350.0               0.900668                0.813724
# 4                      325.0               1.114668                0.872575
#
#    Left pupil (mean-min)  Right pupil (mean-min)  Eye movement type_Fixation  \
# 0               1.105847                0.910546                      3959.0
# 1               0.637200                0.728525                      4235.0
# 2               0.893674                0.771920                      2070.0
# 3               1.069332                0.886276                      3194.0
# 4               1.005332                0.867425                      2605.0
#
#    Eye movement type_Saccade  Eye movement type_Unclassified
# 0                     1996.0                          1115.0
# 1                     1909.0                           842.0
# 2                     2232.0                          1920.0
# 3                     4429.0                          4043.0
# 4                     4969.0                          3920.0

# %%
test_group.shape
# Out:
# (142, 12)

# %%
control_group.shape
# Out:
# (360, 12)

# %% [markdown]
# #### The target variable 'Empathy score' should be attached to the above dataframe.

# %%
test_group = test_group.merge(emp_score, on='Participant', how='inner')
control_group = control_group.merge(emp_score, on='Participant', how='inner')

# %%
test_group.head()
# Out:
#    Participant  Recording name  Gaze point X  Gaze point Y  \
# 0         10.0             1.0    971.247027    441.096289
# 1         10.0             2.0    978.398370    484.556360
# 2         10.0             3.0    998.712701    554.162540
# 3         10.0             4.0   1003.353020    587.964254
# 4         14.0             2.0   1016.897923    481.736213
#
#    Gaze event duration - Max  Left pupil (max-mean)  Right pupil (max-mean)  \
# 0                     1017.0               0.872613                2.897901
# 1                     3476.0               1.630469                2.920098
# 2                     6567.0               2.002562                2.109127
# 3                    12156.0               1.269191                0.642110
# 4                      575.0               0.841228                0.882427
#
#    Left pupil (mean-min)  Right pupil (mean-min)  Eye movement type_Fixation  \
# 0               0.827387                1.042099                      5392.0
# 1               0.979531                0.829902                      5283.0
# 2               0.907438                0.750873                      4444.0
# 3               0.960809                0.967890                      3389.0
# 4               0.658772                1.117573                      1182.0
#
#    Eye movement type_Saccade  Eye movement type_Unclassified  Q_IA_og  \
# 0                     1164.0                           466.0       82
# 1                     1097.0                           316.0       82
# 2                     1252.0                           572.0       82
# 3                      849.0                           294.0       82
# 4                      485.0                          5149.0      109
#
#    Q_IA_ext  Q_IB_og  Q_IB_ext  Class
# 0       104       80       102      2
# 1       104       80       102      2
# 2       104       80       102      2
# 3       104       80       102      2
# 4       135      102       128      4

# %% [markdown]
# We are going to retain only Q_IB_ext for the test group

# %%
#dropping the columns that are not required
cols = {'Participant','Recording name', 'Q_IA_og', 'Q_IA_ext', 'Q_IB_og', 'Class'}
test_group = test_group.drop(cols, axis=1)

# %%
test_group.head()
# Out:
#    Gaze point X  Gaze point Y  Gaze event duration - Max  \
# 0    971.247027    441.096289                     1017.0
# 1    978.398370    484.556360                     3476.0
# 2    998.712701    554.162540                     6567.0
# 3   1003.353020    587.964254                    12156.0
# 4   1016.897923    481.736213                      575.0
#
#    Left pupil (max-mean)  Right pupil (max-mean)  Left pupil (mean-min)  \
# 0               0.872613                2.897901               0.827387
# 1               1.630469                2.920098               0.979531
# 2               2.002562                2.109127               0.907438
# 3               1.269191                0.642110               0.960809
# 4               0.841228                0.882427               0.658772
#
#    Right pupil (mean-min)  Eye movement type_Fixation  \
# 0                1.042099                      5392.0
# 1                0.829902                      5283.0
# 2                0.750873                      4444.0
# 3                0.967890                      3389.0
# 4                1.117573                      1182.0
#
#    Eye movement type_Saccade  Eye movement type_Unclassified  Q_IB_ext
# 0                     1164.0                           466.0       102
# 1                     1097.0                           316.0       102
# 2                     1252.0                           572.0       102
# 3                      849.0                           294.0       102
# 4                      485.0                          5149.0       128

# %%
#dropping the columns that are not required, we are going to retain only Q_IA_ext
cols = {'Participant','Recording name', 'Q_IA_og', 'Q_IA_ext', 'Q_IB_ext', 'Class'}
control_group = control_group.drop(cols, axis=1)

# %%
control_group.head()
# Out:
#    Gaze point X  Gaze point Y  Gaze event duration - Max  \
# 0   1070.355771    253.597742                     1242.0
# 1    965.955342    306.260339                      717.0
# 2    945.398773    320.944357                      600.0
# 3    956.205589    382.697346                      608.0
# 4    980.634064    326.117525                      633.0
#
#    Left pupil (max-mean)  Right pupil (max-mean)  Left pupil (mean-min)  \
# 0               0.404153                0.589454               1.105847
# 1               0.472800                0.631475               0.637200
# 2               0.340705                0.361400               0.479295
# 3               0.472690                0.499765               0.527310
# 4               0.548290                0.490739               0.471710
#
#    Right pupil (mean-min)  Eye movement type_Fixation  \
# 0                0.910546                      3959.0
# 1                0.728525                      4235.0
# 2                0.738600                      3987.0
# 3                0.510235                      7003.0
# 4                0.459261                      4903.0
#
#    Eye movement type_Saccade  Eye movement type_Unclassified  Q_IB_og
# 0                     1996.0                          1115.0      101
# 1                     1909.0                           842.0      101
# 2                     2047.0                           992.0      101
# 3                     3057.0                          1417.0      101
# 4                     2068.0                           807.0      101

# %% [markdown]
# ### Test Group model

# %%
X = test_group.drop(['Q_IB_ext'], axis=1 )

Y = test_group['Q_IB_ext']

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.1, random_state=1)

# %%
X_train.shape
# Out:
# (127, 10)

# %%
# define standard scaler
scaler = StandardScaler()
# transform data
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
#control_group_scaled = scaler.fit_transform(control_group)
#final_group_scaled = scaler.fit_transform(final_group)

# %% [markdown]
# #### Random Forest Regressor model for the Test group

# %%
rf_model1 = RandomForestRegressor()
rf_model1.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
#Cross-val score
kf = KFold(n_splits=7, random_state=None)
results=cross_val_score(rf_model1,X_train,Y_train,cv=kf)
print('Cross-Val accuracy - ',np.mean(results))
rf_model1.fit(X_train, Y_train)
# Out:
# Cross-Val accuracy -  0.39137239422951015
# RandomForestRegressor()

# %%
#Test Accuracy
print('Test score - ',rf_model1.score(X_test, Y_test))
# Out:
# Test score -  0.4991021404262942

# %%
Y_pred = rf_model1.predict(X_test)
#calculate RMSE
sqrt(mean_squared_error(Y_test, Y_pred))
# Out:
# 12.212589678961079

# %% [markdown]
# #### Gradient Boost Regressor model for the Test group

# %%
gb_model1 = GradientBoostingRegressor()
gb_model1.fit(X_train, Y_train)
# Out:
# GradientBoostingRegressor()

# %%
#Cross-val score
kf = KFold(n_splits=7, random_state=None)
results=cross_val_score(gb_model1,X_train,Y_train,cv=kf)
print('Cross-Val accuracy - ',np.mean(results))
gb_model1.fit(X_train, Y_train)
# Out:
# Cross-Val accuracy -  0.3825785104211669
# GradientBoostingRegressor()

# %%
print('Test score - ',gb_model1.score(X_test, Y_test))
# Out:
# Test score -  0.5660110517332703

# %%
Y_pred = gb_model1.predict(X_test)
#calculate RMSE
sqrt(mean_squared_error(Y_test, Y_pred))
# Out:
# 11.36769762246962

# %% [markdown]
# ### Control Group model

# %%
X = control_group.drop(['Q_IB_og'], axis=1 )

Y = control_group['Q_IB_og']

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.1, random_state=1)

# %%
# define standard scaler
scaler = StandardScaler()
# transform data
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
#control_group_scaled = scaler.fit_transform(control_group)
#final_group_scaled = scaler.fit_transform(final_group)

# %% [markdown]
# #### Random Forest Regressor model for the Control group

# %%
rf_model2 = RandomForestRegressor()
rf_model2.fit(X_train, Y_train)
# Out:
# RandomForestRegressor()

# %%
#Cross-val score
kf = KFold(n_splits=10, random_state=None)
results=cross_val_score(rf_model2,X_train,Y_train,cv=kf)
print('Cross-Val accuracy - ',np.mean(results))
rf_model2.fit(X_train, Y_train)
# Out:
# Cross-Val accuracy -  0.6274462639764553
# RandomForestRegressor()

# %%
print('Test score - ',rf_model2.score(X_test, Y_test))
# Out:
# Test score -  0.7951350038023546

# %%
Y_pred = rf_model2.predict(X_test)
#calculate RMSE
sqrt(mean_squared_error(Y_test, Y_pred))
# Out:
# 4.05231895201857

# %% [markdown]
# #### Gradient Boost Regressor model for the Control group

# %%
gb_model2 = GradientBoostingRegressor()
gb_model2.fit(X_train, Y_train)
# Out:
# GradientBoostingRegressor()

# %%
#Cross-val score
kf = KFold(n_splits=10, random_state=None)
results=cross_val_score(gb_model2,X_train,Y_train,cv=kf)
print('Cross-Val accuracy - ',np.mean(results))
gb_model2.fit(X_train, Y_train)
# Out:
# Cross-Val accuracy -  0.5686362525108876
# GradientBoostingRegressor()

# %%
print('Test score - ',gb_model2.score(X_test, Y_test))
# Out:
# Test score -  0.8166571189861176

# %%
Y_pred = gb_model2.predict(X_test)
#calculate RMSE
sqrt(mean_squared_error(Y_test, Y_pred))
# Out:
# 3.8335556002757034

# %% [markdown]
# ### Another approach - Classifying the empathy scores into 4 categories

# %%
trials_data.head()
# Out:
#    Participant  Recording name  Gaze point X  Gaze point Y  \
# 0          1.0             1.0   1070.355771    253.597742
# 1          1.0             2.0    965.955342    306.260339
# 2          3.0            11.0   1017.325455    555.689808
# 3          3.0            12.0    984.012235    588.452621
# 4          3.0            13.0   1005.079682    534.013693
#
#    Gaze event duration - Max  Left pupil (max-mean)  Right pupil (max-mean)  \
# 0                     1242.0               0.404153                0.589454
# 1                      717.0               0.472800                0.631475
# 2                      500.0               0.916326                0.548080
# 3                      350.0               0.900668                0.813724
# 4                      325.0               1.114668                0.872575
#
#    Left pupil (mean-min)  Right pupil (mean-min)  Eye movement type_Fixation  \
# 0               1.105847                0.910546                      3959.0
# 1               0.637200                0.728525                      4235.0
# 2               0.893674                0.771920                      2070.0
# 3               1.069332                0.886276                      3194.0
# 4               1.005332                0.867425                      2605.0
#
#    Eye movement type_Saccade  Eye movement type_Unclassified
# 0                     1996.0                          1115.0
# 1                     1909.0                           842.0
# 2                     2232.0                          1920.0
# 3                     4429.0                          4043.0
# 4                     4969.0                          3920.0

# %%
trials_data_emp = trials_data.merge(emp_score, on='Participant', how='inner')
trials_data_emp
# Out:
#      Participant  Recording name  Gaze point X  Gaze point Y  \
# 0            1.0             1.0   1070.355771    253.597742
# 1            1.0             2.0    965.955342    306.260339
# 2            1.0             3.0    945.398773    320.944357
# 3            1.0             4.0    956.205589    382.697346
# 4            1.0             5.0    980.634064    326.117525
# ..           ...             ...           ...           ...
# 497         20.0             4.0    873.097778    348.956349
# 498         22.0             1.0    843.135480    489.088460
# 499         22.0             2.0    778.052670    444.224280
# 500         22.0             3.0    772.105281    409.056004
# 501         22.0             4.0    786.375090    375.548347
#
#      Gaze event duration - Max  Left pupil (max-mean)  Right pupil (max-mean)  \
# 0                       1242.0               0.404153                0.589454
# 1                        717.0               0.472800                0.631475
# 2                        600.0               0.340705                0.361400
# 3                        608.0               0.472690                0.499765
# 4                        633.0               0.548290                0.490739
# ..                         ...                    ...                     ...
# 497                     4048.0               1.205493                1.016968
# 498                     1458.0               0.460149                0.477857
# 499                     1521.0               0.774306                0.555542
# 500                     1138.0               0.570868                0.516661
# 501                      742.0               0.535303                0.608235
#
#      Left pupil (mean-min)  Right pupil (mean-min)  \
# 0                 1.105847                0.910546
# 1                 0.637200                0.728525
# 2                 0.479295                0.738600
# 3                 0.527310                0.510235
# 4                 0.471710                0.459261
# ..                     ...                     ...
# 497               1.304507                1.303032
# 498               1.649851                1.052143
# 499               1.495694                1.354458
# 500               1.469132                1.253339
# 501               1.324697                1.171765
#
#      Eye movement type_Fixation  Eye movement type_Saccade  \
# 0                        3959.0                     1996.0
# 1                        4235.0                     1909.0
# 2                        3987.0                     2047.0
# 3                        7003.0                     3057.0
# 4                        4903.0                     2068.0
# ..                          ...                        ...
# 497                      4504.0                     1100.0
# 498                      4097.0                      966.0
# 499                      4200.0                     1245.0
# 500                      3332.0                     1063.0
# 501                      2741.0                      791.0
#
#      Eye movement type_Unclassified  Q_IA_og  Q_IA_ext  Q_IB_og  Q_IB_ext  \
# 0                            1115.0      100       125      101       127
# 1                             842.0      100       125      101       127
# 2                             992.0      100       125      101       127
# 3                            1417.0      100       125      101       127
# 4                             807.0      100       125      101       127
# ..                              ...      ...       ...      ...       ...
# 497                           805.0       95       117      106       132
# 498                          1278.0       89       108       95       121
# 499                          1613.0       89       108       95       121
# 500                          1706.0       89       108       95       121
# 501                          2098.0       89       108       95       121
#
#      Class
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
# ..     ...
# 497      4
# 498      3
# 499      3
# 500      3
# 501      3
#
# [502 rows x 17 columns]

# %%
corr = trials_data_emp.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_98b5f_row0_col0, #T_98b5f_row1_col1, #T_98b5f_row2_col2, #T_98b5f_row3_col3, #T_98b5f_row4_col4, #T_98b5f_row5_col5, #T_98b5f_row6_col6, #T_98b5f_row7_col7, #T_98b5f_row8_col8, #T_98b5f_row9_col9, #T_98b5f_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_98b5f_row0_col1 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_98b5f_row0_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_98b5f_row0_col3, #T_98b5f_row1_col7, #T_98b5f_row7_col10, #T_98b5f_row8_col0 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_98b5f_row0_col4, #T_98b5f_row8_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_98b5f_row0_col5, #T_98b5f_row3_col10, #T_98b5f_row10_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_98b5f_row0_col6, #T_98b5f_row0_col7, #T_98b5f_row0_col9, #T_98b5f_row1_col10, #T_98b5f_row5_col8, #T_98b5f_row7_col0, #T_98b5f_row10_col1, #T_98b5f_row10_col2, #T_98b5f_row10_col3, #T_98b5f_row10_col4, #T_98b5f_row10_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_98b5f_row0_col8 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_98b5f_row0_col10 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_98b5f_row1_col0, #T_98b5f_row1_col8, #T_98b5f_row2_col8 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_98b5f_row1_col2 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_98b5f_row1_col3, #T_98b5f_row1_col4 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_98b5f_row1_col5, #T_98b5f_row7_col3 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_98b5f_row1_col6 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_98b5f_row1_col9 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_98b5f_row2_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_98b5f_row2_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_98b5f_row2_col3, #T_98b5f_row10_col9 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_98b5f_row2_col4, #T_98b5f_row9_col7 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_98b5f_row2_col5 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_98b5f_row2_col6, #T_98b5f_row3_col0, #T_98b5f_row7_col6, #T_98b5f_row8_col2 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_98b5f_row2_col7 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_98b5f_row2_col9, #T_98b5f_row4_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_98b5f_row2_col10 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_98b5f_row3_col1, #T_98b5f_row7_col2 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_98b5f_row3_col2 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_98b5f_row3_col4 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_98b5f_row3_col5 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_98b5f_row3_col6, #T_98b5f_row6_col3 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_98b5f_row3_col7, #T_98b5f_row4_col7, #T_98b5f_row6_col1 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_98b5f_row3_col8 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_98b5f_row3_col9 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_98b5f_row4_col1 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_98b5f_row4_col2, #T_98b5f_row9_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_98b5f_row4_col3 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_98b5f_row4_col5, #T_98b5f_row5_col3 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_98b5f_row4_col6 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_98b5f_row4_col8 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_98b5f_row4_col9 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_98b5f_row4_col10 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_98b5f_row5_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_98b5f_row5_col1, #T_98b5f_row9_col10 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_98b5f_row5_col2 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_98b5f_row5_col4 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_98b5f_row5_col6, #T_98b5f_row8_col7 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_98b5f_row5_col7, #T_98b5f_row6_col2 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_98b5f_row5_col9, #T_98b5f_row10_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_98b5f_row5_col10 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_98b5f_row6_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_98b5f_row6_col4 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_98b5f_row6_col5 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_98b5f_row6_col7 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_98b5f_row6_col8 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_98b5f_row6_col9 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_98b5f_row6_col10 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_98b5f_row7_col1 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_98b5f_row7_col4, #T_98b5f_row9_col5 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_98b5f_row7_col5, #T_98b5f_row8_col6, #T_98b5f_row9_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_98b5f_row7_col8 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_98b5f_row7_col9 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_98b5f_row8_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_98b5f_row8_col3, #T_98b5f_row10_col7 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_98b5f_row8_col4 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_98b5f_row8_col9 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_98b5f_row8_col10 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_98b5f_row9_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_98b5f_row9_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_98b5f_row9_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_98b5f_row9_col6 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_98b5f_row9_col8 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_98b5f_row10_col8 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_98b5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98b5f_level0_col0" class="col_heading level0 col0" >Gaze point X</th>
#       <th id="T_98b5f_level0_col1" class="col_heading level0 col1" >Gaze point Y</th>
#       <th id="T_98b5f_level0_col2" class="col_heading level0 col2" >Gaze event duration - Max</th>
#       <th id="T_98b5f_level0_col3" class="col_heading level0 col3" >Left pupil (max-mean)</th>
#       <th id="T_98b5f_level0_col4" class="col_heading level0 col4" >Right pupil (max-mean)</th>
#       <th id="T_98b5f_level0_col5" class="col_heading level0 col5" >Left pupil (mean-min)</th>
#       <th id="T_98b5f_level0_col6" class="col_heading level0 col6" >Right pupil (mean-min)</th>
#       <th id="T_98b5f_level0_col7" class="col_heading level0 col7" >Eye movement type_Fixation</th>
#       <th id="T_98b5f_level0_col8" class="col_heading level0 col8" >Eye movement type_Saccade</th>
#       <th id="T_98b5f_level0_col9" class="col_heading level0 col9" >Eye movement type_Unclassified</th>
#       <th id="T_98b5f_level0_col10" class="col_heading level0 col10" >Class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98b5f_level0_row0" class="row_heading level0 row0" >Gaze point X</th>
#       <td id="T_98b5f_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_98b5f_row0_col1" class="data row0 col1" >-0.106872</td>
#       <td id="T_98b5f_row0_col2" class="data row0 col2" >-0.103869</td>
#       <td id="T_98b5f_row0_col3" class="data row0 col3" >0.029393</td>
#       <td id="T_98b5f_row0_col4" class="data row0 col4" >-0.067179</td>
#       <td id="T_98b5f_row0_col5" class="data row0 col5" >-0.071125</td>
#       <td id="T_98b5f_row0_col6" class="data row0 col6" >-0.167768</td>
#       <td id="T_98b5f_row0_col7" class="data row0 col7" >-0.229583</td>
#       <td id="T_98b5f_row0_col8" class="data row0 col8" >-0.021264</td>
#       <td id="T_98b5f_row0_col9" class="data row0 col9" >-0.164812</td>
#       <td

# %%
#We are going to retain only Class amongst the empathy scores as the target variable
#dropping the columns that are not required
cols = {'Participant','Recording name', 'Q_IA_og', 'Q_IA_ext', 'Q_IB_og', 'Q_IB_ext'}
trials_data_emp = trials_data_emp.drop(cols, axis=1)

# %% [markdown]
# ### Classification model

# %%
X = trials_data_emp.drop(['Class'], axis=1 )

Y = trials_data_emp['Class']

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.1, random_state=1)

# %%
# define standard scaler
scaler = StandardScaler()
# transform data
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# #### Random Forest Classifier

# %%
rf_cl = RandomForestClassifier()
rf_cl.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
#Cross-val score
kf = KFold(n_splits=10, random_state=None)
results=cross_val_score(rf_cl,X_train,Y_train,cv=kf)
print('Cross-Val accuracy - ',np.mean(results))
rf_cl.fit(X_train, Y_train)
# Out:
# Cross-Val accuracy -  0.8048309178743962
# RandomForestClassifier()

# %%
Y_predict = rf_cl.predict(X_test)
print('Test score - ',rf_cl.score(X_test, Y_test))
# Out:
# Test score -  0.803921568627451

# %%
pd.DataFrame(data={'Predictions': Y_predict, 'Actual': Y_test})
# Out:
#      Predictions  Actual
# 306            3       3
# 342            3       3
# 47             4       4
# 67             3       3
# 376            3       3
# ..           ...     ...
# 497            2       4
# 358            3       3
# 372            3       3
# 102            3       3
# 164            4       4
#
# [51 rows x 2 columns]

# %% [markdown]
# #### Gradient Boosting Classifier

# %%
gb_cl = GradientBoostingClassifier()
gb_cl.fit(X_train, Y_train)
# Out:
# GradientBoostingClassifier()

# %%
#Cross-val score
kf = KFold(n_splits=10, random_state=None)
results=cross_val_score(gb_cl,X_train,Y_train,cv=kf)
print('Cross-Val accuracy - ',np.mean(results))
gb_cl.fit(X_train, Y_train)
# Out:
# Cross-Val accuracy -  0.7871497584541063
# GradientBoostingClassifier()

# %%
Y_predict = gb_cl.predict(X_test)

print('Test score - ', gb_cl.score(X_test, Y_test))
# Out:
# Test score -  0.7647058823529411

# %%
pd.DataFrame(data={'Predictions': Y_predict, 'Actual': Y_test})
# Out:
#      Predictions  Actual
# 306            3       3
# 342            3       3
# 47             4       4
# 67             3       3
# 376            3       3
# ..           ...     ...
# 497            2       4
# 358            3       3
# 372            3       3
# 102            3       3
# 164            4       4
#
# [51 rows x 2 columns]

# %% [markdown]
# ### Conclusion
# The task of this project is to attempt to investigate how effectively empathy of an individual can be predicted using his/her eye tracking data. As observed, the regression models struggle to predict empathy on a continuous scale with just the eye-tracking data that is available. However, empathy is something that is subjective and which cannot be assigned a very accurate number on a continuous scale. So, the other approach is to convert the continous scale into 4 classes and build a classification model and investigate how effectively we can classify the participants into their respective empathy classes. This might be a better approach, as evidenced by the consistant train and test scores achieved by both Random Forest Classifier and the Gradient Boosting Classifier.

# %% [markdown]
# ************END****************
